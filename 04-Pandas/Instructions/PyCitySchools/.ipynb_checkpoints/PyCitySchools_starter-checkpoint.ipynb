# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
pd.set_option("display.precision", 2)

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
sdc_df = school_data_complete
sdc_df.head()
sdc_df = sdc_df.rename(columns = {"Student ID":"student_id","School ID":"school_id"})


tot_num_schools = len(sdc_df.school_name.unique())
tot_num_students = len(sdc_df.student_id.unique())
tot_school_budget = sdc_df.budget.unique().sum()
avg_math_score = sdc_df.math_score.mean()
avg_read_score = sdc_df.reading_score.mean()

per_pass_math = (len(sdc_df[sdc_df.math_score >= 70])/tot_num_students)* 100
per_pass_read = (len(sdc_df[sdc_df.reading_score >= 70])/tot_num_students)* 100

pass_math_and_reading_df = sdc_df.loc[(sdc_df["math_score"] >= 70) & (
    sdc_df["reading_score"] >= 70), :]

# %%
sdc_df.head()
# Out:
#    student_id       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  school_id      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
per_pass_math_read = len(pass_math_and_reading_df)/tot_num_students *100.00
per_pass_math_read
# Out:
# 65.17232575950983

# %%
district_summary_df = pd.DataFrame({"Total Number of Schools: ": [tot_num_schools],
                              "Total Number of Students:": tot_num_students,
                              "Total School Budget:": tot_school_budget,
                              "Average Math Score:": avg_math_score,
                              "Average Reading Score:": avg_read_score,
                              "Percent Passing Math:": per_pass_math,
                              "Percent Passing Reading:": per_pass_read,
                              "Percent Passed Math and Reading:": per_pass_math_read
                              })

# %%
#district_summary_df.style.format({"Total School Budget": "${:20,.0f}", 
#                          "Average Math Score": "{:20,.0f}", 
#                          "Average Reading Score": "{:20,.0f}",
#                          "Percent Passing Math":"{:20,.0f}"})

district_summary_df.style.format({"Total School Budget": "${:20,.0f}"})
district_summary_df
# Out:
#    Total Number of Schools:   Total Number of Students:  Total School Budget:  \
# 0                         15                      39170              24649428
#
#    Average Math Score:  Average Reading Score:  Percent Passing Math:  \
# 0                78.99                   81.88                  74.98
#
#    Percent Passing Reading:  Percent Passed Math and Reading:
# 0                     85.81                             65.17

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_list = sdc_df.school_name.unique()

for x, name in enumerate (school_list):
    if x == 0:
        school_summary = CreateSchoolsDF(name, sdc_df)
    else:
        school_temp = CreateSchoolsDF(name, sdc_df)
        school_summary = pd.concat([school_summary, school_temp], ignore_index=True)

# %%
school_summary
# Out:
#              School Name   School Size: School Type  Total School Budget:  \
# 0       Huang High School          2917    District               1910635
# 1    Figueroa High School          2949    District               1884411
# 2     Shelton High School          1761     Charter               1056600
# 3   Hernandez High School          4635    District               3022020
# 4     Griffin High School          1468     Charter                917500
# 5      Wilson High School          2283     Charter               1319574
# 6     Cabrera High School          1858     Charter               1081356
# 7      Bailey High School          4976    District               3124928
# 8      Holden High School           427     Charter                248087
# 9        Pena High School           962     Charter                585858
# 10     Wright High School          1800     Charter               1049400
# 11  Rodriguez High School          3999    District               2547363
# 12    Johnson High School          4761    District               3094650
# 13       Ford High School          2739    District               1763916
# 14     Thomas High School          1635     Charter               1043130
#
#     Average Math Score:  Average Reading Score:  Percent Passing Math:  \
# 0                 76.63                   81.18                  65.68
# 1                 76.71                   81.16                  65.99
# 2                 83.36                   83.73                  93.87
# 3                 77.29                   80.93                  66.75
# 4                 83.35                   83.82                  93.39
# 5                 83.27                   83.99                  93.87
# 6                 83.06                   83.98                  94.13
# 7                 77.05                   81.03                  66.68
# 8                 83.80                   83.81                  92.51
# 9                 83.84                   84.04                  94.59
# 10                83.68                   83.95                  93.33
# 11                76.84                   80.74                  66.37
# 12                77.07                   80.97                  66.06
# 13                77.10                   80.75                  68.31
# 14                83.42                   83.85                  93.27
#
#     Percent Passing Reading:  Overall Passing Percentage:
# 0                      81.32                        53.51
# 1                      80.74                        53.20
# 2                      95.85                        89.89
# 3                      80.86                        53.53
# 4                      97.14                        90.60
# 5                      96.54                        90.58
# 6                      97.04                        91.33
# 7                      81.93                        54.64
# 8                      96.25                        89.23
# 9                      95.95                        90.54
# 10                     96.61                        90.33
# 11                     80.22                        52.99
# 12                     81.22                        53.54
# 13                     79.30                        54.29
# 14                     97.31                        90.95

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
data_sorted = school_summary.sort_values('Overall Passing Percentage:',ascending=False)
data_sorted.head(5)
# Out:
#            School Name   School Size: School Type  Total School Budget:  \
# 6   Cabrera High School          1858     Charter               1081356
# 14   Thomas High School          1635     Charter               1043130
# 4   Griffin High School          1468     Charter                917500
# 5    Wilson High School          2283     Charter               1319574
# 9      Pena High School           962     Charter                585858
#
#     Average Math Score:  Average Reading Score:  Percent Passing Math:  \
# 6                 83.06                   83.98                  94.13
# 14                83.42                   83.85                  93.27
# 4                 83.35                   83.82                  93.39
# 5                 83.27                   83.99                  93.87
# 9                 83.84                   84.04                  94.59
#
#     Percent Passing Reading:  Overall Passing Percentage:
# 6                      97.04                        91.33
# 14                     97.31                        90.95
# 4                      97.14                        90.60
# 5                      96.54                        90.58
# 9                      95.95                        90.54

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
data_sorted = school_summary.sort_values('Overall Passing Percentage:',ascending=True)
data_sorted.head(5)
# Out:
#              School Name   School Size: School Type  Total School Budget:  \
# 11  Rodriguez High School          3999    District               2547363
# 1    Figueroa High School          2949    District               1884411
# 0       Huang High School          2917    District               1910635
# 3   Hernandez High School          4635    District               3022020
# 12    Johnson High School          4761    District               3094650
#
#     Average Math Score:  Average Reading Score:  Percent Passing Math:  \
# 11                76.84                   80.74                  66.37
# 1                 76.71                   81.16                  65.99
# 0                 76.63                   81.18                  65.68
# 3                 77.29                   80.93                  66.75
# 12                77.07                   80.97                  66.06
#
#     Percent Passing Reading:  Overall Passing Percentage:
# 11                     80.22                        52.99
# 1                      80.74                        53.20
# 0                      81.32                        53.51
# 3                      80.86                        53.53
# 12                     81.22                        53.54

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
school_list = sdc_df.school_name.unique()

# %%
school_list = sdc_df.school_name.unique()
x = 0
for x, name in enumerate (school_list):

    if x == 0:
        school_grade_summary = GetGradeScoreSummary("9th", name, sdc_df)
        school_grade_temp = GetGradeScoreSummary("10th", name, sdc_df)
        school_grade_summary = pd.concat([school_grade_summary, school_grade_temp], ignore_index=True)   
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("11th", name, sdc_df)], ignore_index=True)  
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("12th", name, sdc_df)], ignore_index=True)

    else:
        
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("9th", name, sdc_df)], ignore_index=True)
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("10th", name, sdc_df)], ignore_index=True)
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("11th", name, sdc_df)], ignore_index=True)          
        school_grade_summary = pd.concat([school_grade_summary, GetGradeScoreSummary("12th", name, sdc_df)], ignore_index=True)
        
school_grade_summary
# Out:
#    Grade:                School:  Number of Students:  Average Math Score:  \
# 0     9th      Huang High School                  844                77.03
# 1    10th      Huang High School                  767                75.91
# 2    11th      Huang High School                  721                76.45
# 3    12th      Huang High School                  585                77.23
# 4     9th   Figueroa High School                  856                76.40
# 5    10th   Figueroa High School                  763                76.54
# 6    11th   Figueroa High School                  709                76.88
# 7    12th   Figueroa High School                  621                77.15
# 8     9th    Shelton High School                  530                83.42
# 9    10th    Shelton High School                  448                82.92
# 10   11th    Shelton High School                  412                83.38
# 11   12th    Shelton High School                  371                83.78
# 12    9th  Hernandez High School                 1382                77.44
# 13   10th  Hernandez High School                 1227                77.34
# 14   11th  Hernandez High School                 1088                77.14
# 15   12th  Hernandez High School                  938                77.19
# 16    9th    Griffin High School                  409                82.04
# 17   10th    Griffin High School                  406                84.23
# 18   11th    Griffin High School                  361                83.84
# 19   12th    Griffin High School                  292                83.36
# 20    9th     Wilson High School                  631                83.09
# 21   10th     Wilson High School                  606                83.72
# 22   11th     Wilson High School                  599                83.20
# 23   12th     Wilson High School                  447                83.04
# 24    9th    Cabrera High School                  528                83.09
# 25   10th    Cabrera High School                  466                83.15
# 26   11th    Cabrera High School                  482                82.77
# 27   12th    Cabrera High School                  382                83.28
# 28    9th     Bailey High School                 1458                77.08
# 29   10th     Bailey High School                 1239                77.00
# 30   11th     Bailey High School                 1251                77.52
# 31   12th     Bailey High School                 1028                76.49
# 32    9th     Holden High School                  127                83.79
# 33   10th     Holden High School                  114                83.43
# 34   11th     Holden High School                  103                85.00
# 35   12th     Holden High School                   83                82.86
# 36    9th       Pena High School                  275                83.63
# 37   10th       Pena High School                  250                83.37
# 38   11th       Pena High School                  256                84.33
# 39   12th       Pena High School                  181                84.12
# 40    9th     Wright High School                  510                83.26
# 41   10th     Wright High School                  486                84.01
# 42   11th     Wright High School                  435                83.84
# 43   12th     Wright High School                  369                83.64
# 44    9th  Rodriguez High School                 1164                76.86
# 45   10th  Rodriguez High School                 1040                76.61
# 46   11th  Rodriguez High School                 1006                76.40
# 47   12th  Rodriguez High School                  789                77.69
# 48    9th    Johnson High School                 1400                77.19
# 49   10th    Johnson High School                 1227                76.69
# 50   11th    Johnson High School                 1198                77.49
# 51   12th    Johnson High School                  936                76.86
# 52    9th       Ford High School                  833                77.36
# 53   10th       Ford High School                  708                77.67
# 54   11th       Ford High School                  659                76.92
# 55   12th       Ford High School                  539                76.18
# 56    9th     Thomas High School                  461                83.59
# 57   10th     Thomas High School                  421                83.09
# 58   11th     Thomas High School                  415                83.50
# 59   12th     Thomas High School                  338                83.50
#
#     Average Reading Score:  Percent Passing Math:  Percent Passing Reading:  \
# 0                    81.29                  68.13                     81.28
# 1                    81.51                  63.49                     82.14
# 2                    81.42                  64.77                     80.58
# 3                    80.31                  66.15                     81.20
# 4                    81.20                  64.14                     81.54
# 5                    81.41                  66.58                     81.26
# 6                    80.64                  65.30                     78.14
# 7                    81.38                  68.60                     81.96
# 8                    84.12                  93.40                     96.79
# 9                    83.44                  93.30                     93.75
# 10                   84.37                  94.90                     97.33
# 11                   82.78                  94.07                     95.42
# 12                   80.87                  66.71                     81.11
# 13                   80.66                  66.75                     80.68
# 14                   81.40                  66.82                     81.71
# 15                   80.86                  66.74                     79.74
# 16                   83.37                  92.42                     96.09
# 17                   83.71                  94.09                     97.29
# 18                   84.29                  94.18                     97.51
# 19                   84.01                  92.81                     97.95
# 20                   83.94                  93.34                     96.83
# 21                   84.02                  94.22                     96.20
# 22                   83.76                  93.66                     96.66
# 23                   84.32                  94.41                     96.42
# 24                   83.68                  95.27                     96.78
# 25                   84.25                  93.99                     97.42
# 26                   83.79                  92.32                     97.10
# 27                   84.29                  95.03                     96.86
# 28                   81.30                  67.15                     82.17
# 29                   80.91                  66.34                     83.54
# 30                   80.95                  68.43                     80.58
# 31                   80.91                  64.30                     81.32
# 32                   83.68                  91.34                     94.49
# 33                   83.32                  92.98                     96.49
# 34                   83.82                  91.26                     96.12
# 35                   84.70                  95.18                     98.80
# 36                   83.81                  93.09                     98.18
# 37                   83.61                  94.40                     95.60
# 38                   84.34                  96.09                     94.92
# 39                   84.59                  95.03                     94.48
# 40                   83.83                  94.12                     95.88
# 41                   83.81                  93.21                     96.91
# 42                   84.16                  92.64                     97.24
# 43                   84.07                  93.22                     96.48
# 44                   80.99                  66.41                     80.33
# 45                   80.63                  65.87                     80.29
# 46                   80.86                  65.41                     80.82
# 47                   80.38                  68.19                     79.21
# 48                   81.26                  66.79                     81.86
# 49                   80.77                  65.12                     81.50
# 50                   80.62                  66.94                     79.63
# 51                   81.23                  65.06                     81.94
# 52                   80.63                  68.91                     79.59
# 53                   81.26                  69.35                     79.10
# 54                   80.40                  68.74                     79.97
# 55                   80.66                  65.49                     78.29
# 56                   83.73                  93.49                     98.05
# 57                   84.25                  94.06                     97.62
# 58                   83.59                  92.53                     97.11
# 59                   83.83                  92.90                     96.15
#
#     Overall Passing Percentage:
# 0                         54.38
# 1                         52.67
# 2                         53.40
# 3                         53.50
# 4                         52.92
# 5                         53.74
# 6                         50.35
# 7                         56.20
# 8                         90.38
# 9                         87.50
# 10                        92.23
# 11                        89.49
# 12                        53.84
# 13                        52.81
# 14                        54.23
# 15                        53.20
# 16                        88.75
# 17                        91.38
# 18                        91.69
# 19                        90.75
# 20                        90.17
# 21                        90.76
# 22                        90.48
# 23                        91.05
# 24                        92.23
# 25                        91.42
# 26                        89.83
# 27                        91.88
# 28                        55.08
# 29                        55.69
# 30                        55.24
# 31                        52.04
# 32                        86.61
# 33                        90.35
# 34                        87.38
# 35                        93.98
# 36                        91.27
# 37                        90.00
# 38                        91.02
# 39                        89.50
# 40                        90.39
# 41                        90.74
# 42                        90.34
# 43                        89.70
# 44                        53.61
# 45                        52.40
# 46                        52.29
# 47                        53.74
# 48                        54.43
# 49                        53.06
# 50                        52.75
# 51                        53.85
# 52                        55.94
# 53                        54.80
# 54                        54.02
# 55                        51.39
# 56                        91.76
# 57                        91.92
# 58                        90.12
# 59                        89.64

# %%
math_scores_by_grade_df = school_grade_summary[["Grade:","School:","Percent Passing Math:"]]

math_scores_by_grade_df.head(10)
# Out:
#   Grade:               School:  Percent Passing Math:
# 0    9th     Huang High School                  68.13
# 1   10th     Huang High School                  63.49
# 2   11th     Huang High School                  64.77
# 3   12th     Huang High School                  66.15
# 4    9th  Figueroa High School                  64.14
# 5   10th  Figueroa High School                  66.58
# 6   11th  Figueroa High School                  65.30
# 7   12th  Figueroa High School                  68.60
# 8    9th   Shelton High School                  93.40
# 9   10th   Shelton High School                  93.30

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
read_scores_by_grade_df = school_grade_summary[["Grade:","School:","Percent Passing Reading:"]]
read_scores_by_grade_df.head(10)
# Out:
#   Grade:               School:  Percent Passing Reading:
# 0    9th     Huang High School                     81.28
# 1   10th     Huang High School                     82.14
# 2   11th     Huang High School                     80.58
# 3   12th     Huang High School                     81.20
# 4    9th  Figueroa High School                     81.54
# 5   10th  Figueroa High School                     81.26
# 6   11th  Figueroa High School                     78.14
# 7   12th  Figueroa High School                     81.96
# 8    9th   Shelton High School                     96.79
# 9   10th   Shelton High School                     93.75

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
data_sort_spending_df = school_summary[["School Name ","Total School Budget:","Average Math Score:"]]
data_sort_spending_df.head(10)
data_sorted = school_summary.sort_values("Total School Budget:",ascending=False)
data_sort_spending_df.head(5)

data_sort_spending_df
# Out:
#              School Name   Total School Budget:  Average Math Score:
# 0       Huang High School               1910635                76.63
# 1    Figueroa High School               1884411                76.71
# 2     Shelton High School               1056600                83.36
# 3   Hernandez High School               3022020                77.29
# 4     Griffin High School                917500                83.35
# 5      Wilson High School               1319574                83.27
# 6     Cabrera High School               1081356                83.06
# 7      Bailey High School               3124928                77.05
# 8      Holden High School                248087                83.80
# 9        Pena High School                585858                83.84
# 10     Wright High School               1049400                83.68
# 11  Rodriguez High School               2547363                76.84
# 12    Johnson High School               3094650                77.07
# 13       Ford High School               1763916                77.10
# 14     Thomas High School               1043130                83.42

# %%
data_sorted = school_summary.sort_values('Average Math Score:',ascending=True)
data_sorted.head(5)
# Out:
#              School Name   School Size: School Type  Total School Budget:  \
# 0       Huang High School          2917    District               1910635
# 1    Figueroa High School          2949    District               1884411
# 11  Rodriguez High School          3999    District               2547363
# 7      Bailey High School          4976    District               3124928
# 12    Johnson High School          4761    District               3094650
#
#     Average Math Score:  Average Reading Score:  Percent Passing Math:  \
# 0                 76.63                   81.18                  65.68
# 1                 76.71                   81.16                  65.99
# 11                76.84                   80.74                  66.37
# 7                 77.05                   81.03                  66.68
# 12                77.07                   80.97                  66.06
#
#     Percent Passing Reading:  Overall Passing Percentage:
# 0                      81.32                        53.51
# 1                      80.74                        53.20
# 11                     80.22                        52.99
# 7                      81.93                        54.64
# 12                     81.22                        53.54

# %%
data_sort_spending_df = school_summary[["School Name ","Total School Budget:","Average Reading Score:"]]
data_sort_spending_df.head(10)
data_sorted = school_summary.sort_values("Total School Budget:",ascending=False)
data_sort_spending_df.head(5)
# Out:
#             School Name   Total School Budget:  Average Reading Score:
# 0      Huang High School               1910635                   81.18
# 1   Figueroa High School               1884411                   81.16
# 2    Shelton High School               1056600                   83.73
# 3  Hernandez High School               3022020                   80.93
# 4    Griffin High School                917500                   83.82

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
data_sort_spending_df = school_summary[["School Name ","School Size:","Average Math Score:"]]
data_sort_spending_df.head(10)
data_sorted = school_summary.sort_values("School Size:",ascending=False)
data_sort_spending_df.head(5)
# Out:
#             School Name   School Size:  Average Math Score:
# 0      Huang High School          2917                76.63
# 1   Figueroa High School          2949                76.71
# 2    Shelton High School          1761                83.36
# 3  Hernandez High School          4635                77.29
# 4    Griffin High School          1468                83.35

# %%
data_sort_spending_df = school_summary[["School Name ","School Size:","Average Reading Score:"]]
data_sort_spending_df.head(10)
data_sorted = school_summary.sort_values("School Size:",ascending=False)
data_sort_spending_df.head(5)
# Out:
#             School Name   School Size:  Average Reading Score:
# 0      Huang High School          2917                   81.18
# 1   Figueroa High School          2949                   81.16
# 2    Shelton High School          1761                   83.73
# 3  Hernandez High School          4635                   80.93
# 4    Griffin High School          1468                   83.82

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
data_sort_spending_df = school_summary[["School Name ","School Type","Average Reading Score:"]]
data_sort_spending_df.head(10)
data_sorted = school_summary.sort_values("School Type",ascending=False)
data_sort_spending_df.head(5)
# Out:
#             School Name  School Type  Average Reading Score:
# 0      Huang High School    District                   81.18
# 1   Figueroa High School    District                   81.16
# 2    Shelton High School     Charter                   83.73
# 3  Hernandez High School    District                   80.93
# 4    Griffin High School     Charter                   83.82

# %% [markdown]
# ## Function Definitions

# %%
def CreateSchoolsDF(school_name, district):
    schools_df = district.loc[district["school_name"] == school_name, :]
    school_name = schools_df.iloc[0].loc["school_name"]
    school_size = schools_df.iloc[0].loc["size"]
    school_type = schools_df.iloc[0].loc["type"]
    school_budget = schools_df.iloc[0].loc["budget"]
    school_per_stu_budget = school_budget/school_size
    avg_math_score = schools_df.math_score.mean()
    avg_read_score = schools_df.reading_score.mean()
    school_per_pass_math = (len(schools_df[schools_df.math_score >= 70])/school_size)* 100
    school_per_pass_read = (len(schools_df[schools_df.reading_score >= 70])/school_size)* 100
    school_pass_math_and_reading_df = schools_df.loc[(schools_df["math_score"] >= 70) & (
    schools_df["reading_score"] >= 70), :]
    school_overallpass = len(school_pass_math_and_reading_df)/school_size *100.00

    school_summary_df = pd.DataFrame({"School Name ": [school_name],
                                  "School Size:": school_size,
                                  "School Type" : school_type,
                                  "Total School Budget:": school_budget,
                                  "Average Math Score:": avg_math_score,
                                  "Average Reading Score:": avg_read_score,
                                  "Percent Passing Math:": school_per_pass_math,
                                  "Percent Passing Reading:": school_per_pass_read,
                                  "Overall Passing Percentage:": school_overallpass,
                                  })

    return school_summary_df

# %%
def GetGradeScoreSummary(grade, school_name, data_df):
    school_df = sdc_df.loc[data_df["school_name"] == school_name, :]
    grade_df = school_df.loc[school_df["grade"] == grade ]
    total_num_students = len(grade_df)
    
    avg_math_score = grade_df.math_score.mean()
    avg_read_score = grade_df.reading_score.mean()
    per_pass_math = (len(grade_df[grade_df.math_score >= 70])/total_num_students)* 100
    per_pass_read = (len(grade_df[grade_df.reading_score >= 70])/total_num_students)* 100
    pass_math_and_reading_df = grade_df.loc[(grade_df["math_score"] >= 70) & (
        grade_df["reading_score"] >= 70), :]
    per_pass_math_read = len(pass_math_and_reading_df)/total_num_students *100.00
    per_pass_math_read
    
    
    score_summary_df = pd.DataFrame({"Grade:": [grade],
                                  "School:" : school_name,
                                  "Number of Students:":total_num_students,
                                  "Average Math Score:": avg_math_score,
                                  "Average Reading Score:": avg_read_score,
                                  "Percent Passing Math:": per_pass_math,
                                  "Percent Passing Reading:": per_pass_read,
                                  "Overall Passing Percentage:": per_pass_math_read
                                  })
    return score_summary_df
